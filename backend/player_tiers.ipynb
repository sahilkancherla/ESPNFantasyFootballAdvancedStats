# %%
from dotenv import load_dotenv
import os
from espn_api.football import League
from util.player_tiers_helper import get_tier_to_players_by_team

# %%
load_dotenv()

league_id = os.getenv('LEAGUE_ID')
swid = os.getenv('SWID')
espn_s2 = os.getenv('ESPN_S2')

# %%
year = 2024

# %%
league = League(league_id=league_id, year=year, espn_s2=espn_s2, swid=swid)

# %%
tier_size = 9

# %%
tiers_to_players = get_tier_to_players_by_team(league, tier_size, 0)

# %%
tiers_to_players
# Out:
# {1: {'RB_4': [4242335, 4040761],
#   'WR_1': [4047646, 4426388, 3128390],
#   'RB_1': [4379399],
#   'WR_8': [4035687],
#   'WR_4': [4595348],
#   'TE_2': [4361307],
#   'RB_7': [4361579],
#   'WR_10': [4430878],
#   'RB_6': [4569987],
#   'QB_1': [3916387, 4426348],
#   'D/ST_3': [-16033],
#   'RB_10': [4596334],
#   'K_2': [4362081]},
#  2: {'RB_3': [4430807],
#   'RB_2': [4361529],
#   'RB_1': [3054850],
#   'WR_5': [4429615],
#   'WR_3': [4428331, 4241478],
#   'WR_8': [15818],
#   'K_3': [15683],
#   'TE_1': [4432665],
#   'D/ST_2': [-16025],
#   'D/ST_1': [-16023],
#   'WR_4': [4569618],
#   'QB_1': [4036378, 3052587],
#   'TE_2': [4385690],
#   'RB_4': [4038441]},
#  3: {'WR_4': [4362628],
#   'RB_1': [3929630, 4241985],
#   'WR_2': [3126486],
#   'RB_3': [4697815],
#   'TE_4': [3116365],
#   'QB_1': [4429084],
#   'WR_10': [2976499, 3121422],
#   'WR_3': [4426354],
#   'RB_10': [3128720],
#   'RB_2': [4372019],
#   'RB_6': [3051926],
#   'WR_12': [15795],
#   'K_3': [4360234, 4686361],
#   'D/ST_1': [-16026]},
#  4: {'RB_2': [4427366],
#   'RB_4': [3043078, 3068267],
#   'WR_2': [4258173, 4683062, 4372016],
#   'WR_8': [4360438],
#   'WR_4': [4248528],
#   'TE_2': [3123076],
#   'RB_3': [4426385],
#   'D/ST_2': [-16005],
#   'K_4': [14993],
#   'QB_2': [4432577],
#   'TE_5': [3051876],
#   'RB_5': [4259545],
#   'TE_1': [4361050]},
#  5: {'WR_10': [4374302],
#   'WR_13': [4432708],
#   'WR_1': [16737],
#   'QB_2': [3139477],
#   'RB_1': [3116385, 4569173],
#   'RB_6': [2576414, 4361777],
#   'RB_2': [3916148],
#   'WR_3': [4432773],
#   'RB_7': [4429275, 4373626],
#   'TE_2': [15847],
#   'D/ST_1': [-16024],
#   'RB_4': [4429013],
#   'K_1': [17372],
#   'WR_4': [2310331]},
#  6: {'WR_1': [3116406, 4032473],
#   'RB_4': [4239996, 4241457],
#   'WR_7': [4426515],
#   'TE_1': [4430027],
#   'WR_2': [2976212, 4373678],
#   'K_1': [3953687],
#   'RB_3': [3051392],
#   'WR_6': [4635008],
#   'WR_8': [4429205],
#   'D/ST_4': [-16020],
#   'RB_5': [4242431],
#   'WR_12': [4431299],
#   'RB_1': [3042519],
#   'QB_1': [4040715]},
#  7: {'WR_3': [4262921, 4612826],
#   'WR_8': [4047650],
#   'RB_3': [4047365, 4430737],
#   'RB_2': [3045147, 4241474],
#   'TE_1': [4360248],
#   'WR_1': [4362249],
#   'QB_3': [3915511],
#   'TE_3': [4242355],
#   'QB_2': [2577417],
#   'D/ST_4': [-16012],
#   'K_2': [3055899],
#   'WR_5': [3915416],
#   'WR_14': [4239993]},
#  8: {'RB_2': [4429795, 4567048],
#   'WR_11': [4361370],
#   'WR_10': [4426502],
#   'WR_1': [2977187],
#   'QB_2': [3917315],
#   'RB_10': [4678008],
#   'WR_7': [3128429],
#   'QB_4': [4431611],
#   'RB_5': [4428557],
#   'RB_4': [4596448],
#   'WR_5': [16800],
#   'TE_2': [3040151],
#   'WR_13': [4597500],
#   'K_1': [4372066],
#   'D/ST_3': [-16030],
#   'RB_8': [4241416]},
#  9: {'RB_10': [3117251],
#   'WR_3': [4241389],
#   'RB_1': [4429160, 4360569],
#   'QB_1': [3918298],
#   'WR_6': [4366031, 3925357],
#   'RB_2': [4035538],
#   'WR_10': [3932905],
#   'WR_9': [3895856],
#   'WR_2': [3116165],
#   'RB_3': [4035676],
#   'D/ST_1': [-16006],
#   'K_2': [3050478],
#   'TE_3': [2468609],
#   'TE_6': [4036133],
#   'RB_9': [4682745]},
#  10: {'RB_10': [4240750], 'K_4': [4266790]}}
