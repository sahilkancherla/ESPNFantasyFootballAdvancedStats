# %%
from dotenv import load_dotenv
import os
from espn_api.football import League
from util.player_tiers_helper import get_tier_to_players_by_team

# %%
load_dotenv()

league_id = os.getenv('LEAGUE_ID')
swid = os.getenv('SWID')
espn_s2 = os.getenv('ESPN_S2')

# %%
year = 2024

# %%
league = League(league_id=league_id, year=year, espn_s2=espn_s2, swid=swid)

# %%
tier_size = 9

# %%
tiers_to_players = get_tier_to_players_by_team(league, tier_size, 100)

# %%
tiers_to_players
# Out:
# {1: {'RB_3': [4242335, 4379399],
#   'WR_1': [4047646],
#   'WR_5': [4035687],
#   'WR_3': [4595348],
#   'TE_1': [4361307],
#   'RB_5': [4361579, 4569987],
#   'WR_6': [4430878],
#   'RB_4': [4040761],
#   'QB_1': [3916387, 4426348],
#   'D/ST_1': [-16015],
#   'D/ST_2': [-16033],
#   'WR_8': [4426388],
#   'RB_6': [4596334],
#   'K_1': [4362081]},
#  2: {'RB_2': [4430807, 4361529],
#   'RB_1': [3054850],
#   'WR_3': [4429615],
#   'WR_2': [4428331, 4241478],
#   'WR_6': [15818],
#   'RB_4': [4362238, 4038815],
#   'K_2': [15683],
#   'TE_1': [4432665],
#   'D/ST_3': [-16025],
#   'D/ST_1': [-16023],
#   'WR_8': [4569618],
#   'QB_1': [4036378],
#   'TE_3': [4385690]},
#  3: {'WR_3': [4362628, 4426354],
#   'RB_1': [3929630, 4241985],
#   'WR_8': [3126486, 15795],
#   'RB_2': [4697815, 4372019],
#   'TE_2': [3116365],
#   'QB_1': [4429084],
#   'WR_7': [2976499, 3121422],
#   'RB_7': [3128720],
#   'RB_5': [3051926],
#   'K_2': [4360234],
#   'D/ST_2': [-16004],
#   'D/ST_1': [-16026]},
#  4: {'RB_7': [4427366],
#   'RB_3': [3043078, 4426385],
#   'WR_1': [4258173, 4683062],
#   'WR_9': [4360438, 3045138],
#   'WR_3': [4248528],
#   'RB_4': [3068267, 4259545],
#   'TE_1': [3123076],
#   'D/ST_2': [-16005],
#   'K_2': [14993],
#   'WR_2': [4372016],
#   'QB_2': [4432577],
#   'TE_3': [3051876]},
#  5: {'WR_7': [4374302],
#   'WR_8': [4432708],
#   'WR_1': [16737],
#   'QB_2': [3139477],
#   'RB_1': [3116385, 4569173],
#   'RB_5': [2576414, 4429275],
#   'RB_4': [4361777],
#   'RB_2': [3916148],
#   'WR_2': [4432773],
#   'K_1': [3917232],
#   'RB_6': [4373626],
#   'WR_4': [3916433],
#   'TE_1': [15847],
#   'D/ST_2': [-16001]},
#  6: {'WR_1': [3116406, 2976212],
#   'RB_3': [4239996, 4241457],
#   'WR_5': [4426515, 4429205],
#   'TE_2': [4430027],
#   'K_1': [3953687],
#   'RB_2': [3051392],
#   'WR_4': [4635008],
#   'D/ST_3': [-16020],
#   'RB_4': [4242431],
#   'WR_8': [4431299],
#   'RB_1': [3042519],
#   'QB_1': [4040715],
#   'D/ST_1': [-16016]},
#  7: {'WR_2': [4262921, 4612826],
#   'WR_6': [4047650],
#   'RB_3': [4047365],
#   'RB_1': [3045147],
#   'TE_1': [4360248],
#   'RB_2': [4241474],
#   'WR_1': [4362249],
#   'QB_3': [3915511],
#   'TE_2': [4242355],
#   'QB_2': [2577417],
#   'D/ST_3': [-16012],
#   'K_1': [3055899],
#   'WR_4': [3915416],
#   'WR_9': [4239993],
#   'RB_6': [4430737]},
#  8: {'RB_6': [4429795],
#   'WR_7': [4361370, 4426502, 4427095],
#   'RB_1': [4567048],
#   'WR_5': [2977187, 3128429],
#   'QB_2': [3917315],
#   'RB_7': [4678008, 4429096],
#   'QB_3': [4431611],
#   'RB_4': [4428557],
#   'K_2': [3049899],
#   'D/ST_1': [-16018],
#   'RB_3': [4596448],
#   'WR_3': [16800],
#   'TE_3': [3040151]},
#  9: {'RB_7': [3117251, 4360569],
#   'WR_2': [4241389],
#   'RB_1': [4429160],
#   'QB_1': [3918298],
#   'WR_4': [4366031, 3925357],
#   'RB_5': [4035538, 4722893],
#   'WR_6': [3932905, 3895856],
#   'WR_1': [3116165],
#   'RB_2': [4035676],
#   'D/ST_1': [-16006],
#   'K_1': [3050478],
#   'TE_2': [2468609],
#   'TE_3': [4036133]},
#  10: {'RB_7': [4240750], 'K_2': [4266790]}}
